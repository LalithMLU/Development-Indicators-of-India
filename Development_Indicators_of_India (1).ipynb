# %% [markdown]
# This notebook focuses on analyzing development indicators in India using a dataset that contains various metrics such as fertility rates, school enrollment rates, CO2 emissions, and other socioeconomic and environmental factors. The goal is to clean the dataset, perform exploratory data analysis (EDA), and visualize key indicators to understand trends and insights related to India's development over time and is compared with the development indicators of USA.

# %%
#This cell mounts Google Drive to access files stored in the user's drive, which is necessary for loading the dataset stored there.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#imports the pandas library and loads the dataset to inspect its structure and contents.
import pandas as pd

# Load the dataset to inspect its structure and content
dataset = pd.read_csv('/content/drive/MyDrive/development factors.csv')

# Display the first few rows of the dataset to understand its structure
dataset.head(20)
# Out:
#      Country Name                                              India  \
# 0    Country Code                                                IND
# 1     Series Name  Adolescent fertility rate (births per 1,000 wo...
# 2     Series Code                                        SP.ADO.TFRT
# 3   2014 [YR2014]                                             34.643
# 4   2015 [YR2015]                                             22.432
# 5   2016 [YR2016]                                             20.025
# 6   2017 [YR2017]                                              20.42
# 7   2018 [YR2018]                                             19.275
# 8   2019 [YR2019]                                             17.701
# 9   2020 [YR2020]                                             17.278
# 10  2021 [YR2021]                                             17.234
# 11  2022 [YR2022]                                             16.299
# 12  2023 [YR2023]                                                 ..
#
# ...

# %%
#dropping rows which are unneccessary for analysis
dataset.drop([0,2])
# Out:
#      Country Name                                              India  \
# 1     Series Name  Adolescent fertility rate (births per 1,000 wo...
# 3   2014 [YR2014]                                             34.643
# 4   2015 [YR2015]                                             22.432
# 5   2016 [YR2016]                                             20.025
# 6   2017 [YR2017]                                              20.42
# 7   2018 [YR2018]                                             19.275
# 8   2019 [YR2019]                                             17.701
# 9   2020 [YR2020]                                             17.278
# 10  2021 [YR2021]                                             17.234
# 11  2022 [YR2022]                                             16.299
# 12  2023 [YR2023]                                                 ..
#
#                                               India.1  \
# 1   Agriculture, forestry, and fishing, value adde...
# ...

# %%
#converting the first column as header of the dataset
dataset.columns = dataset.iloc[1]

# %%
dataset = dataset[1:]

# %%
dataset.head()
# Out:
# 1    Series Name  \
# 3  2014 [YR2014]
# 4  2015 [YR2015]
# 5  2016 [YR2016]
# 6  2017 [YR2017]
# 7  2018 [YR2018]
#
# 1 Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 3                                             34.643
# 4                                             22.432
# 5                                             20.025
# 6                                              20.42
# 7                                             19.275
#
# 1 Agriculture, forestry, and fishing, value added (% of GDP)  \
# 3                                        16.79193451
# 4                                        16.17450811
# 5                                        16.36380056
# 6                                         16.5583314
# 7                                        16.03163069
#
# 1 Annual freshwater withdrawals, total (% of internal resources)  \
# 3                                        44.77869986
# 4                                        44.77869986
# ...

# %%
dataset = dataset.drop([2])

# %%
#replacing the values of series column for easy reading and simpler understanding
year_changed = dataset.replace({'2014 [YR2014]':2014,
                 '2015 [YR2015]':2015,
                 '2016 [YR2016]':2016,
                 '2017 [YR2017]':2017,
                 '2018 [YR2018]':2018,
                 '2019 [YR2019]':2019,
                 '2020 [YR2020]':2020,
                 '2021 [YR2021]':2021,
                 '2022 [YR2022]':2022,
                 '2023 [YR2023]':2023})
# Out:
# <ipython-input-23-706b725aeb2c>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   year_changed = dataset.replace({'2014 [YR2014]':2014,

# %%
year_changed.head(13)
# Out:
# 1   Series Name Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 3          2014                                             34.643
# 4          2015                                             22.432
# 5          2016                                             20.025
# 6          2017                                              20.42
# 7          2018                                             19.275
# 8          2019                                             17.701
# 9          2020                                             17.278
# 10         2021                                             17.234
# 11         2022                                             16.299
# 12         2023                                                 ..
#
# 1  Agriculture, forestry, and fishing, value added (% of GDP)  \
# 3                                         16.79193451
# 4                                         16.17450811
# ...

# %%
#replacing the special charaters to NULL values
import numpy as np
replaced_characters = year_changed.replace('..',np.NaN)
# Out:
# <ipython-input-29-394c57705d8d>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   replaced_characters = year_changed.replace('..',np.NaN)

# %%
#checking which columns are containing null values
replaced_characters.isnull().sum()
# Out:
# 1
# Series Name                                                                     0
# Adolescent fertility rate (births per 1,000 women ages 15-19)                   1
# Agriculture, forestry, and fishing, value added (% of GDP)                      0
# Annual freshwater withdrawals, total (% of internal resources)                  3
# Births attended by skilled health staff (% of total)                            7
# CO2 emissions (metric tons per capita)                                          3
# Contraceptive prevalence, any method (% of married women ages 15-49)            7
# Domestic credit provided by financial sector (% of GDP)                        10
# Electric power consumption (kWh per capita)                                     9
# Energy use (kg of oil equivalent per capita)                                    9
# Exports of goods and services (% of GDP)                                        0
# ...

# %%
replaced_characters.head(13)
# Out:
# 1   Series Name Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 3          2014                                             34.643
# 4          2015                                             22.432
# 5          2016                                             20.025
# 6          2017                                              20.42
# 7          2018                                             19.275
# 8          2019                                             17.701
# 9          2020                                             17.278
# 10         2021                                             17.234
# 11         2022                                             16.299
# 12         2023                                                NaN
#
# 1  Agriculture, forestry, and fishing, value added (% of GDP)  \
# 3                                         16.79193451
# 4                                         16.17450811
# ...

# %%
#dropping the columns which are having a greater number of NULL values, these type of columns will not be helpfull during the analysis process
unwanted_columns = replaced_characters.drop({'Contraceptive prevalence, any method (% of married women ages 15-49)',
                                             'Domestic credit provided by financial sector (% of GDP)',
                                             'Electric power consumption (kWh per capita)',
                                             'Energy use (kg of oil equivalent per capita)',
                                             },axis=1)

# %%
unwanted_columns.head()
# Out:
# 1  Series Name Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 3         2014                                             34.643
# 4         2015                                             22.432
# 5         2016                                             20.025
# 6         2017                                              20.42
# 7         2018                                             19.275
#
# 1 Agriculture, forestry, and fishing, value added (% of GDP)  \
# 3                                        16.79193451
# 4                                        16.17450811
# 5                                        16.36380056
# 6                                         16.5583314
# 7                                        16.03163069
#
# 1 Annual freshwater withdrawals, total (% of internal resources)  \
# 3                                        44.77869986
# 4                                        44.77869986
# ...

# %%
#handling the missing values, here we are filling the null values with a forward fill method
missing_values = unwanted_columns.fillna(method='ffill',axis=1)
# Out:
# <ipython-input-35-77b48f5c223b>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   missing_values = unwanted_columns.fillna(method='ffill',axis=1)

# %%
missing_values.head(13)
# Out:
# 1  Series Name Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 3         2014                                             34.643
# 4         2015                                             22.432
# 5         2016                                             20.025
# 6         2017                                              20.42
# 7         2018                                             19.275
# 8         2019                                             17.701
# 9         2020                                             17.278
# 10        2021                                             17.234
# 11        2022                                             16.299
# 12        2023                                               2023
#
# 1  Agriculture, forestry, and fishing, value added (% of GDP)  \
# 3                                         16.79193451
# 4                                         16.17450811
# 5                                         16.36380056
# ...

# %%
#obtaining all the column names
missing_values.columns
# Out:
# Index(['Series Name',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
#        'Annual freshwater withdrawals, total (% of internal resources)',
#        'Births attended by skilled health staff (% of total)',
#        'CO2 emissions (metric tons per capita)',
#        'Exports of goods and services (% of GDP)',
#        'External debt stocks, total (DOD, current US$)',
#        'Fertility rate, total (births per woman)',
#        'Foreign direct investment, net inflows (BoP, current US$)',
#        'Forest area (sq. km)', 'GDP (current US$)', 'GDP growth (annual %)',
#        'GNI per capita, Atlas method (current US$)',
#        'GNI per capita, PPP (current international $)',
#        'GNI, Atlas method (current US$)', 'GNI, PPP (current international $)',
#        'Gross capital formation (% of GDP)',
#        'High-technology exports (% of manufactured exports)',
# ...

# %%
# Dictionary for simplified column names
simplified_names = {
    'Series Name': 'Series',
    'Adolescent fertility rate (births per 1,000 women ages 15-19)': 'Adolescent Fertility Rate',
    'Agriculture, forestry, and fishing, value added (% of GDP)': 'Agriculture Value Added (% GDP)',
    'Annual freshwater withdrawals, total (% of internal resources)': 'Freshwater Withdrawals (% Internal Resources)',
    'Births attended by skilled health staff (% of total)': 'Skilled Birth Attendance (%)',
    'CO2 emissions (metric tons per capita)': 'CO2 Emissions (tons per capita)',
    'Exports of goods and services (% of GDP)': 'Exports (% GDP)',
    'External debt stocks, total (DOD, current US$)': 'External Debt (US$)',
    'Fertility rate, total (births per woman)': 'Total Fertility Rate',
    'Foreign direct investment, net inflows (BoP, current US$)': 'FDI Inflows (US$)',
    'Forest area (sq. km)': 'Forest Area (sq km)',
    'GDP (current US$)': 'GDP (US$)',
    'GDP growth (annual %)': 'GDP Growth (%)',
    'GNI per capita, Atlas method (current US$)': 'GNI per Capita (US$)',
    'GNI per capita, PPP (current international $)': 'GNI per Capita (PPP)',
    'GNI, Atlas method (current US$)': 'GNI (US$)',
    'GNI, PPP (current international $)': 'GNI (PPP)',
    'Gross capital formation (% of GDP)': 'Capital Formation (% GDP)',
    'High-technology exports (% of manufactured exports)': 'High-Tech Exports (% of Manufactured)',
    'Immunization, measles (% of children ages 12-23 months)': 'Measles Immunization (%)',
    'Imports of goods and services (% of GDP)': 'Imports (% GDP)',
    'Income share held by lowest 20%': 'Income Share (Lowest 20%)',
    'Industry (including construction), value added (% of GDP)': 'Industry Value Added (% GDP)',
    'Inflation, GDP deflator (annual %)': 'Inflation Rate (%)',
    'Life expectancy at birth, total (years)': 'Life Expectancy (years)',
    'Merchandise trade (% of GDP)': 'Merchandise Trade (% GDP)',
    'Military expenditure (% of GDP)': 'Military Expenditure (% GDP)',
    'Mobile cellular subscriptions (per 100 people)': 'Mobile Subscriptions (per 100 people)',
    'Mortality rate, under-5 (per 1,000 live births)': 'Under-5 Mortality Rate',
    'Net barter terms of trade index (2015 = 100)': 'Terms of Trade Index',
    'Net migration': 'Net Migration',
    'Net official development assistance and official aid received (current US$)': 'Development Aid Received (US$)',
    'Personal remittances, received (current US$)': 'Personal Remittances (US$)',
    'Population density (people per sq. km of land area)': 'Population Density (per sq km)',
    'Population growth (annual %)': 'Population Growth Rate (%)',
    'Population, total': 'Total Population',
    'Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)': 'Poverty Rate ($2.15/day)',
    'Poverty headcount ratio at national poverty lines (% of population)': 'National Poverty Rate',
    'Prevalence of HIV, total (% of population ages 15-49)': 'HIV Prevalence (%)',
    'Prevalence of underweight, weight for age (% of children under 5)': 'Underweight Prevalence (% Children <5)',
    'Primary completion rate, total (% of relevant age group)': 'Primary Completion Rate (%)',
    'Revenue, excluding grants (% of GDP)': 'Revenue (% GDP)',
    'School enrollment, primary (% gross)': 'Primary School Enrollment (% Gross)',
    'School enrollment, primary and secondary (gross), gender parity index (GPI)': 'School Enrollment GPI',
    'School enrollment, secondary (% gross)': 'Secondary School Enrollment (% Gross)',
    'Surface area (sq. km)': 'Surface Area (sq km)',
    'Tax revenue (% of GDP)': 'Tax Revenue (% GDP)',
    'Terrestrial and marine protected areas (% of total territorial area)': 'Protected Areas (% Total Area)',
    'Time required to start a business (days)': 'Time to Start Business (days)',
    'Total debt service (% of exports of goods, services and primary income)': 'Debt Service (% Exports)',
    'Urban population growth (annual %)': 'Urban Population Growth (%)'
}

# Renaming columns in the dataframe why because these column names are very lenghty
renamed_columns = missing_values.rename(columns=simplified_names)

# %%
renamed_columns.head(10)
# Out:
# 1  Series Adolescent Fertility Rate Agriculture Value Added (% GDP)  \
# 3    2014                    34.643                     16.79193451
# 4    2015                    22.432                     16.17450811
# 5    2016                    20.025                     16.36380056
# 6    2017                     20.42                      16.5583314
# 7    2018                    19.275                     16.03163069
# 8    2019                    17.701                      16.7555683
# 9    2020                    17.278                     18.66853766
# 10   2021                    17.234                     17.37256153
# 11   2022                    16.299                     16.63943104
# 12   2023                      2023                      15.9660077
#
# 1  Freshwater Withdrawals (% Internal Resources) Skilled Birth Attendance (%)  \
# 3                                    44.77869986                         81.4
# ...

# %%
renamed_columns.isnull().sum()
# Out:
# 1
# Series                                           0
# Adolescent Fertility Rate                        0
# Agriculture Value Added (% GDP)                  0
# Freshwater Withdrawals (% Internal Resources)    0
# Skilled Birth Attendance (%)                     0
# CO2 Emissions (tons per capita)                  0
# Exports (% GDP)                                  0
# External Debt (US$)                              0
# Total Fertility Rate                             0
# FDI Inflows (US$)                                0
# Forest Area (sq km)                              0
# GDP (US$)                                        0
# GDP Growth (%)                                   0
# GNI per Capita (US$)                             0
# GNI per Capita (PPP)                             0
# GNI (US$)                                        0
# GNI (PPP)                                        0
# Capital Formation (% GDP)                        0
# ...

# %%
renamed_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 3 to 12
# Data columns (total 51 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Series                                         10 non-null     object
#  1   Adolescent Fertility Rate                      10 non-null     object
#  2   Agriculture Value Added (% GDP)                10 non-null     object
#  3   Freshwater Withdrawals (% Internal Resources)  10 non-null     object
#  4   Skilled Birth Attendance (%)                   10 non-null     object
#  5   CO2 Emissions (tons per capita)                10 non-null     object
#  6   Exports (% GDP)                                10 non-null     object
#  7   External Debt (US$)                            10 non-null     object
#  8   Total Fertility Rate                           10 non-null     object
# ...

# %%
#converting all the columns datatype to integer, this will be helpful while visualizing and analyzing
renamed_columns[renamed_columns.columns] = renamed_columns[renamed_columns.columns].astype(float)

# %%
renamed_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 3 to 12
# Data columns (total 51 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Series                                         10 non-null     float64
#  1   Adolescent Fertility Rate                      10 non-null     float64
#  2   Agriculture Value Added (% GDP)                10 non-null     float64
#  3   Freshwater Withdrawals (% Internal Resources)  10 non-null     float64
#  4   Skilled Birth Attendance (%)                   10 non-null     float64
#  5   CO2 Emissions (tons per capita)                10 non-null     float64
#  6   Exports (% GDP)                                10 non-null     float64
#  7   External Debt (US$)                            10 non-null     float64
#  8   Total Fertility Rate                           10 non-null     float64
# ...

# %%
renamed_columns.describe()
# Out:
# 1          Series  Adolescent Fertility Rate  Agriculture Value Added (% GDP)  \
# count    10.00000                  10.000000                        10.000000
# mean   2018.50000                 220.830700                        16.732231
# std       3.02765                 633.239851                         0.797705
# min    2014.00000                  16.299000                        15.966008
# 25%    2016.25000                  17.383750                        16.221831
# 50%    2018.50000                  19.650000                        16.598881
# 75%    2020.75000                  21.929000                        16.782843
# max    2023.00000                2023.000000                        18.668538
#
# 1      Freshwater Withdrawals (% Internal Resources)  \
# count                                      10.000000
# mean                                       36.342890
# std                                        13.586992
# ...

# %%
#storing the dataframe as a csv file for later use
renamed_columns.to_csv('Devlopment_Indicators_cleaned.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/Devlopment_Indicators_cleaned.csv')
df.head()
# Out:
#    Series  Adolescent Fertility Rate  Agriculture Value Added (% GDP)  \
# 0    2014                     34.643                        16.791935
# 1    2015                     22.432                        16.174508
# 2    2016                     20.025                        16.363801
# 3    2017                     20.420                        16.558331
# 4    2018                     19.275                        16.031631
#
#    Freshwater Withdrawals (% Internal Resources)  \
# 0                                        44.7787
# 1                                        44.7787
# 2                                        44.7787
# 3                                        44.7787
# 4                                        44.7787
#
#    Skilled Birth Attendance (%)  CO2 Emissions (tons per capita)  \
# 0                       81.4000                         1.642465
# 1                       44.7787                         1.631323
# ...

# %%
#renaming the series column as year, this name would be more appropriate while plotting graphs
df = df.rename(columns={'Series':'year'})

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading a csv file which containts development indicators data of USA
usa = pd.read_csv('/content/drive/MyDrive/development factors (USA).csv')
usa.head()
# Out:
#     Country Name                                      United States  \
# 0   Country Code                                                USA
# 1    Series Name  Adolescent fertility rate (births per 1,000 wo...
# 2    Series Code                                        SP.ADO.TFRT
# 3  2014 [YR2014]                                             24.036
# 4  2015 [YR2015]                                             21.899
#
#                                      United States.1  \
# 0                                                USA
# 1  Agriculture, forestry, and fishing, value adde...
# 2                                     NV.AGR.TOTL.ZS
# 3                                        1.168240492
# 4                                        1.028904091
#
#                                      United States.2  \
# 0                                                USA
# 1  Annual freshwater withdrawals, total (% of int...
# 2                                     ER.H2O.FWTL.ZS
# ...

# %%
#Dropping rows 0 and 2 because they are of no use
usa.drop([0,2])

# %%
usa.head()
# Out:
#     Country Name                                      United States  \
# 1    Series Name  Adolescent fertility rate (births per 1,000 wo...
# 3  2014 [YR2014]                                             24.036
# 4  2015 [YR2015]                                             21.899
# 5  2016 [YR2016]                                             19.867
# 6  2017 [YR2017]                                             18.423
#
#                                      United States.1  \
# 1  Agriculture, forestry, and fishing, value adde...
# 3                                        1.168240492
# 4                                        1.028904091
# 5                                        0.937140438
# 6                                        0.940362226
#
#                                      United States.2  \
# 1  Annual freshwater withdrawals, total (% of int...
# 3                                        15.58825016
# 4                                         15.7699117
# ...

# %%
#replacing special characters with a NULL value
import numpy as np
usa_replaced3 = usa.replace('..',np.NaN)

# %%
usa_replaced5 = usa_replaced3

# %%
#Converting the 0th column as Header
usa_replaced5.columns = usa_replaced3.iloc[0]

# %%
usa_replaced5.head()
# Out:
# 1    Series Name  \
# 1    Series Name
# 3  2014 [YR2014]
# 4  2015 [YR2015]
# 5  2016 [YR2016]
# 6  2017 [YR2017]
#
# 1 Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 1  Adolescent fertility rate (births per 1,000 wo...
# 3                                             24.036
# 4                                             21.899
# 5                                             19.867
# 6                                             18.423
#
# 1 Agriculture, forestry, and fishing, value added (% of GDP)  \
# 1  Agriculture, forestry, and fishing, value adde...
# 3                                        1.168240492
# 4                                        1.028904091
# 5                                        0.937140438
# 6                                        0.940362226
#
# 1 Annual freshwater withdrawals, total (% of internal resources)  \
# 1  Annual freshwater withdrawals, total (% of int...
# 3                                        15.58825016
# ...

# %%
usa_replaced5 = usa_replaced5.drop([1])
usa_replaced5.head()
# Out:
# 1    Series Name  \
# 3  2014 [YR2014]
# 4  2015 [YR2015]
# 5  2016 [YR2016]
# 6  2017 [YR2017]
# 7  2018 [YR2018]
#
# 1 Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 3                                             24.036
# 4                                             21.899
# 5                                             19.867
# 6                                             18.423
# 7                                              17.06
#
# 1 Agriculture, forestry, and fishing, value added (% of GDP)  \
# 3                                        1.168240492
# 4                                        1.028904091
# 5                                        0.937140438
# 6                                        0.940362226
# 7                                        0.898498261
#
# 1 Annual freshwater withdrawals, total (% of internal resources)  \
# 3                                        15.58825016
# 4                                         15.7699117
# ...

# %%
#dropping the unwanted columns
usa_unwanted_columns = usa_replaced5.drop({'Contraceptive prevalence, any method (% of married women ages 15-49)',
                                             'Domestic credit provided by financial sector (% of GDP)',
                                             'Electric power consumption (kWh per capita)',
                                             'Energy use (kg of oil equivalent per capita)',
                                             },axis=1)

# %%
# Dictionary for simplified column names
usa_simplified_names = {
    'Series Name': 'Series',
    'Adolescent fertility rate (births per 1,000 women ages 15-19)': 'Adolescent Fertility Rate',
    'Agriculture, forestry, and fishing, value added (% of GDP)': 'Agriculture Value Added (% GDP)',
    'Annual freshwater withdrawals, total (% of internal resources)': 'Freshwater Withdrawals (% Internal Resources)',
    'Births attended by skilled health staff (% of total)': 'Skilled Birth Attendance (%)',
    'CO2 emissions (metric tons per capita)': 'CO2 Emissions (tons per capita)',
    'Exports of goods and services (% of GDP)': 'Exports (% GDP)',
    'External debt stocks, total (DOD, current US$)': 'External Debt (US$)',
    'Fertility rate, total (births per woman)': 'Total Fertility Rate',
    'Foreign direct investment, net inflows (BoP, current US$)': 'FDI Inflows (US$)',
    'Forest area (sq. km)': 'Forest Area (sq km)',
    'GDP (current US$)': 'GDP (US$)',
    'GDP growth (annual %)': 'GDP Growth (%)',
    'GNI per capita, Atlas method (current US$)': 'GNI per Capita (US$)',
    'GNI per capita, PPP (current international $)': 'GNI per Capita (PPP)',
    'GNI, Atlas method (current US$)': 'GNI (US$)',
    'GNI, PPP (current international $)': 'GNI (PPP)',
    'Gross capital formation (% of GDP)': 'Capital Formation (% GDP)',
    'High-technology exports (% of manufactured exports)': 'High-Tech Exports (% of Manufactured)',
    'Immunization, measles (% of children ages 12-23 months)': 'Measles Immunization (%)',
    'Imports of goods and services (% of GDP)': 'Imports (% GDP)',
    'Income share held by lowest 20%': 'Income Share (Lowest 20%)',
    'Industry (including construction), value added (% of GDP)': 'Industry Value Added (% GDP)',
    'Inflation, GDP deflator (annual %)': 'Inflation Rate (%)',
    'Life expectancy at birth, total (years)': 'Life Expectancy (years)',
    'Merchandise trade (% of GDP)': 'Merchandise Trade (% GDP)',
    'Military expenditure (% of GDP)': 'Military Expenditure (% GDP)',
    'Mobile cellular subscriptions (per 100 people)': 'Mobile Subscriptions (per 100 people)',
    'Mortality rate, under-5 (per 1,000 live births)': 'Under-5 Mortality Rate',
    'Net barter terms of trade index (2015 = 100)': 'Terms of Trade Index',
    'Net migration': 'Net Migration',
    'Net official development assistance and official aid received (current US$)': 'Development Aid Received (US$)',
    'Personal remittances, received (current US$)': 'Personal Remittances (US$)',
    'Population density (people per sq. km of land area)': 'Population Density (per sq km)',
    'Population growth (annual %)': 'Population Growth Rate (%)',
    'Population, total': 'Total Population',
    'Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)': 'Poverty Rate ($2.15/day)',
    'Poverty headcount ratio at national poverty lines (% of population)': 'National Poverty Rate',
    'Prevalence of HIV, total (% of population ages 15-49)': 'HIV Prevalence (%)',
    'Prevalence of underweight, weight for age (% of children under 5)': 'Underweight Prevalence (% Children <5)',
    'Primary completion rate, total (% of relevant age group)': 'Primary Completion Rate (%)',
    'Revenue, excluding grants (% of GDP)': 'Revenue (% GDP)',
    'School enrollment, primary (% gross)': 'Primary School Enrollment (% Gross)',
    'School enrollment, primary and secondary (gross), gender parity index (GPI)': 'School Enrollment GPI',
    'School enrollment, secondary (% gross)': 'Secondary School Enrollment (% Gross)',
    'Surface area (sq. km)': 'Surface Area (sq km)',
    'Tax revenue (% of GDP)': 'Tax Revenue (% GDP)',
    'Terrestrial and marine protected areas (% of total territorial area)': 'Protected Areas (% Total Area)',
    'Time required to start a business (days)': 'Time to Start Business (days)',
    'Total debt service (% of exports of goods, services and primary income)': 'Debt Service (% Exports)',
    'Urban population growth (annual %)': 'Urban Population Growth (%)'
}

# Renaming columns in the dataframe
usa_renamed_columns = usa_unwanted_columns.rename(columns=usa_simplified_names)

# %%
usa_renamed_columns.head()
# Out:
# 1         Series Adolescent Fertility Rate Agriculture Value Added (% GDP)  \
# 3  2014 [YR2014]                    24.036                     1.168240492
# 4  2015 [YR2015]                    21.899                     1.028904091
# 5  2016 [YR2016]                    19.867                     0.937140438
# 6  2017 [YR2017]                    18.423                     0.940362226
# 7  2018 [YR2018]                     17.06                     0.898498261
#
# 1 Freshwater Withdrawals (% Internal Resources) Skilled Birth Attendance (%)  \
# 3                                   15.58825016                         98.5
# 4                                    15.7699117                         99.1
# 5                                    15.7699117                         99.1
# 6                                    15.7699117                         99.1
# 7                                    15.7699117                         99.1
#
# ...

# %%
#filling all the NULL cells using a forward fill method
usa_missing_values = usa_renamed_columns.fillna(method='ffill',axis=0)
# Out:
# <ipython-input-112-477ef1e6c9ff>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   usa_missing_values = usa_renamed_columns.fillna(method='ffill',axis=0)
# <ipython-input-112-477ef1e6c9ff>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   usa_missing_values = usa_renamed_columns.fillna(method='ffill',axis=0)

# %%
#Renaming the series column as year
usa_renamed_columns = usa_missing_values.rename(columns={'Series':'year'})

# %%
usa_missing_values.head(10)
# Out:
# 1          Series Adolescent Fertility Rate Agriculture Value Added (% GDP)  \
# 3   2014 [YR2014]                    24.036                     1.168240492
# 4   2015 [YR2015]                    21.899                     1.028904091
# 5   2016 [YR2016]                    19.867                     0.937140438
# 6   2017 [YR2017]                    18.423                     0.940362226
# 7   2018 [YR2018]                     17.06                     0.898498261
# 8   2019 [YR2019]                    16.414                     0.833339958
# 9   2020 [YR2020]                     15.83                     0.937167526
# 10  2021 [YR2021]                    15.966                     0.948221773
# 11  2022 [YR2022]                    15.119                     0.948221773
# 12  2023 [YR2023]                    15.119                     0.948221773
#
# 1  Freshwater Withdrawals (% Internal Resources) Skilled Birth Attendance (%)  \
# ...

# %%
#converting the datatype of the columns,so that it might not cause a problem during the analysis process
usa_renamed_columns[usa_renamed_columns.columns[1:]] = usa_renamed_columns[usa_renamed_columns.columns[1:]].astype(float)

# %%
usa_renamed_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 3 to 12
# Data columns (total 51 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   year                                           10 non-null     object
#  1   Adolescent Fertility Rate                      10 non-null     float64
#  2   Agriculture Value Added (% GDP)                10 non-null     float64
#  3   Freshwater Withdrawals (% Internal Resources)  10 non-null     float64
#  4   Skilled Birth Attendance (%)                   10 non-null     float64
#  5   CO2 Emissions (tons per capita)                10 non-null     float64
#  6   Exports (% GDP)                                10 non-null     float64
#  7   External Debt (US$)                            0 non-null      float64
#  8   Total Fertility Rate                           10 non-null     float64
# ...

# %%
#replacing null values with 0
usa_renamed_columns.replace(np.NaN,0,inplace=True)

# %%
usa_renamed_columns.isnull().sum()
# Out:
# 1
# year                                             0
# Adolescent Fertility Rate                        0
# Agriculture Value Added (% GDP)                  0
# Freshwater Withdrawals (% Internal Resources)    0
# Skilled Birth Attendance (%)                     0
# CO2 Emissions (tons per capita)                  0
# Exports (% GDP)                                  0
# External Debt (US$)                              0
# Total Fertility Rate                             0
# FDI Inflows (US$)                                0
# Forest Area (sq km)                              0
# GDP (US$)                                        0
# GDP Growth (%)                                   0
# GNI per Capita (US$)                             0
# GNI per Capita (PPP)                             0
# GNI (US$)                                        0
# GNI (PPP)                                        0
# Capital Formation (% GDP)                        0
# ...

# %%
#storing the cleaned csv file of USA for later use
usa_renamed_columns.to_csv('/content/drive/MyDrive/usa_cleaned_up.csv')

# %%
#loading both the cleaned files to vartiavles us1 and ind1
us1 = pd.read_csv('/content/drive/MyDrive/usa_cleaned_up.csv')
ind1 = pd.read_csv('/content/drive/MyDrive/Devlopment_Indicators_cleaned.csv')

# %%
us1.head(10)
# Out:
#    Unnamed: 0           year  Adolescent Fertility Rate  \
# 0           3  2014 [YR2014]                     24.036
# 1           4  2015 [YR2015]                     21.899
# 2           5  2016 [YR2016]                     19.867
# 3           6  2017 [YR2017]                     18.423
# 4           7  2018 [YR2018]                     17.060
# 5           8  2019 [YR2019]                     16.414
# 6           9  2020 [YR2020]                     15.830
# 7          10  2021 [YR2021]                     15.966
# 8          11  2022 [YR2022]                     15.119
# 9          12  2023 [YR2023]                     15.119
#
#    Agriculture Value Added (% GDP)  \
# 0                         1.168240
# 1                         1.028904
# 2                         0.937140
# 3                         0.940362
# 4                         0.898498
# 5                         0.833340
# 6                         0.937168
# 7                         0.948222
# ...

# %%
#Concatinating these two dataframes for analysis
ind_us2 = pd.concat((ind1,us1),axis=0)

# %%
ind_us2.head(20)
# Out:
#    Series  Adolescent Fertility Rate  Agriculture Value Added (% GDP)  \
# 0  2014.0                     34.643                        16.791935
# 1  2015.0                     22.432                        16.174508
# 2  2016.0                     20.025                        16.363801
# 3  2017.0                     20.420                        16.558331
# 4  2018.0                     19.275                        16.031631
# 5  2019.0                     17.701                        16.755568
# 6  2020.0                     17.278                        18.668538
# 7  2021.0                     17.234                        17.372562
# 8  2022.0                     16.299                        16.639431
# 9  2023.0                   2023.000                        15.966008
# 0     NaN                     24.036                         1.168240
# 1     NaN                     21.899                         1.028904
# ...

# %%
ind_us2['year'].replace(np.NaN,'India',inplace=True)
# Out:
# <ipython-input-159-63a5817deff9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ind_us2['year'].replace(np.NaN,'India',inplace=True)

# %%
ind_us2['year'].replace({'2014 [YR2014]':'USA',
                 '2015 [YR2015]':'USA',
                 '2016 [YR2016]':'USA',
                 '2017 [YR2017]':'USA',
                 '2018 [YR2018]':'USA',
                 '2019 [YR2019]':'USA',
                 '2020 [YR2020]':'USA',
                 '2021 [YR2021]':'USA',
                 '2022 [YR2022]':'USA',
                 '2023 [YR2023]':'USA'},inplace=True)
# Out:
# <ipython-input-163-c07e0ffb68d6>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ind_us2['year'].replace({'2014 [YR2014]':'USA',

# %%
ind_us2.head(20)
# Out:
#    Series  Adolescent Fertility Rate  Agriculture Value Added (% GDP)  \
# 0  2014.0                     34.643                        16.791935
# 1  2015.0                     22.432                        16.174508
# 2  2016.0                     20.025                        16.363801
# 3  2017.0                     20.420                        16.558331
# 4  2018.0                     19.275                        16.031631
# 5  2019.0                     17.701                        16.755568
# 6  2020.0                     17.278                        18.668538
# 7  2021.0                     17.234                        17.372562
# 8  2022.0                     16.299                        16.639431
# 9  2023.0                   2023.000                        15.966008
# 0     NaN                     24.036                         1.168240
# 1     NaN                     21.899                         1.028904
# ...

# %%
#storing the cleaned csv file as final into the drive
ind_us2.to_csv('final_dataset.csv')

# %%
#loading the stored dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
final = pd.read_csv('/content/drive/MyDrive/final_dataset.csv')

# %%
final.head(20)
# Out:
#       year  Adolescent Fertility Rate  Agriculture Value Added (% GDP)  \
# 0   2014.0                     34.643                        16.791935
# 1   2015.0                     22.432                        16.174508
# 2   2016.0                     20.025                        16.363801
# 3   2017.0                     20.420                        16.558331
# 4   2018.0                     19.275                        16.031631
# 5   2019.0                     17.701                        16.755568
# 6   2020.0                     17.278                        18.668538
# 7   2021.0                     17.234                        17.372562
# 8   2022.0                     16.299                        16.639431
# 9   2023.0                   2023.000                        15.966008
# 10  2014.0                     24.036                         1.168240
# 11  2015.0                     21.899                         1.028904
# ...

# %% [markdown]
# 1. Military Expenditure of countries?

# %%
highest_military_expense = final[['country', 'Military Expenditure (% GDP)']].sort_values(by='Military Expenditure (% GDP)', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='Military Expenditure (% GDP)', data=highest_military_expense)
plt.xticks(rotation=45)
plt.title('Countries with the Highest Military Expenditure (% GDP)')
plt.xlabel('Country')
plt.ylabel('Military Expenditure (% GDP)')
plt.show()

# %% [markdown]
# 2. What is the Distribution of Mobile Cellular Subscriptions?

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=final['Mobile Subscriptions (per 100 people)'])
plt.title('Distribution of Mobile Cellular Subscriptions (per 100 people)')
plt.show()

# %% [markdown]
# This plot helps compare the level of mobile penetratio in India. Countries with a high median value and narrow range typically have widespread and consistent mobile usage, while those with a broader range or lower median may show uneven access or less developed mobile infrastructure.

# %% [markdown]
# 3. How do exports as a percentage of GDP vary by year for a specific country?

# %%
for_corr = final.drop('country',axis=1)

# %%
avg_gdp_growth = final.groupby('country')['GDP Growth (%)'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='GDP Growth (%)', data=avg_gdp_growth)
plt.xticks(rotation=45)
plt.title('Average GDP Growth Rate by Region')
plt.xlabel('Region')
plt.ylabel('GDP Growth (%)')
plt.show()

# %% [markdown]
# This visualization allows you to quickly compare the economic growth trends between India and the USA, offering insights into which country has shown stronger economic performance on average.

# %% [markdown]
# 4. What is the distribution of agriculture value added as a percentage of GDP across countries in a specific year?

# %%
# Scatter plot to show the relationship
plt.figure(figsize=(6, 6))
plt.scatter(final['year'],final['Agriculture Value Added (% GDP)'], color='red')
plt.title('Agriculture Value Added over years')
plt.xlabel('year')
plt.ylabel('Agriculture Value Added')
plt.show()

# %% [markdown]
# This scatter plot helps visualize and compare the agricultural economic contributions of India and the USA, revealing differences in their economic structures and development patterns.

# %% [markdown]
# 5. What is the trend of CO2 emissions over the years for a specific country?

# %%
import matplotlib.pyplot as plt

country = 'India'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['CO2 Emissions (tons per capita)'], marker='o')
plt.title(f'CO2 Emissions Trend in {country}')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (tons per capita)')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot provides insights into each country's environmental impact and development trajectory, emphasizing the need for sustainable practices and emission reduction strategies.

# %%
import matplotlib.pyplot as plt

country = 'USA'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['CO2 Emissions (tons per capita)'], marker='o')
plt.title(f'CO2 Emissions Trend in {country}')
plt.xlabel('Year')
plt.ylabel('CO2 Emissions (tons per capita)')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot provides insights into each country's environmental impact and development trajectory, emphasizing the need for sustainable practices and emission reduction strategies.

# %% [markdown]
# 6. How does the total fertility rate vary by country in a given year?

# %%
import seaborn as sns

year = 2014
year_data = final[final['year'] == year]

plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='Total Fertility Rate', data=year_data)
plt.title(f'Total Fertility Rate by Country in {year}')
plt.xlabel('Country')
plt.ylabel('Total Fertility Rate')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This bar plot provides insights into demographic trends and helps compare fertility patterns across different countries, contributing to a deeper understanding of population growth and its implications on economic and social planning.

# %%
import seaborn as sns

year = 2023
year_data = final[final['year'] == year]

plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='Total Fertility Rate', data=year_data)
plt.title(f'Total Fertility Rate by Country in {year}')
plt.xlabel('Country')
plt.ylabel('Total Fertility Rate')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This bar plot provides insights into demographic trends and helps compare fertility patterns across different countries, contributing to a deeper understanding of population growth and its implications on economic and social planning.

# %% [markdown]
# 7. How does external debt change over time for a specific country?

# %%
country = 'USA'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['External Debt (US$)'], marker='s', color='orange')
plt.title(f'External Debt Over Time in {country}')
plt.xlabel('Year')
plt.ylabel('External Debt (US$)')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot provides insights into the financial health and borrowing patterns of each country, helping to understand their economic strategies and reliance on external funds. It also helps identify periods of significant debt increase or reduction, offering a closer look at the countries' economic management practices.

# %%
country = 'USA'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['External Debt (US$)'], marker='s', color='orange')
plt.title(f'External Debt Over Time in {country}')
plt.xlabel('Year')
plt.ylabel('External Debt (US$)')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot provides insights into the financial health and borrowing patterns of each country, helping to understand their economic strategies and reliance on external funds. It also helps identify periods of significant debt increase or reduction, offering a closer look at the countries' economic management practices.

# %% [markdown]
# 8. How do exports as a percentage of GDP vary by year for a specific country?

# %%
country = 'USA'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.bar(country_data['year'], country_data['Exports (% GDP)'], color='teal')
plt.title(f'Exports as % of GDP Over Time in {country}')
plt.xlabel('Year')
plt.ylabel('Exports (% GDP)')
plt.show()

# %% [markdown]
# This bar plot provides insights into how important exports are for each country's economy and shows how this dependence has evolved over time. It highlights differences in economic structure and trade policies between countries, offering a deeper understanding of economic growth and development patterns.

# %%
country = 'USA'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.bar(country_data['year'], country_data['Exports (% GDP)'], color='teal')
plt.title(f'Exports as % of GDP Over Time in {country}')
plt.xlabel('Year')
plt.ylabel('Exports (% GDP)')
plt.show()

# %% [markdown]
# This bar plot provides insights into how important exports are for each country's economy and shows how this dependence has evolved over time. It highlights differences in economic structure and trade policies between countries, offering a deeper understanding of economic growth and development patterns.

# %% [markdown]
# 9. What is the relationship between FDI inflows and CO2 emissions?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='FDI Inflows (US$)', y='CO2 Emissions (tons per capita)', hue='country', data=final)
plt.title('FDI Inflows vs CO2 Emissions')
plt.xlabel('FDI Inflows (US$)')
plt.ylabel('CO2 Emissions (tons per capita)')
plt.show()

# %% [markdown]
# This scatter plot helps analyze the environmental impact of economic growth driven by FDI, providing insights into sustainable development practices and policies. It highlights the importance of balancing economic expansion with environmental sustainability.

# %% [markdown]
# 10. What is the trend of urban population growth over time for a specific country?

# %%
country = 'USA'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['Urban Population Growth (%)'], marker='o', color='purple')
plt.title(f'Urban Population Growth Trend in {country}')
plt.xlabel('Year')
plt.ylabel('Urban Population Growth (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot shows urban population growth trends across various countries, highlighting factors driving urbanization such as economic opportunities and infrastructure development. It reveals periods of rapid growth, indicating shifts in policies or global events. Understanding these trends is crucial for policymakers and urban planners to address the challenges and opportunities of increasing urbanization.

# %%
country = 'India'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['Urban Population Growth (%)'], marker='o', color='purple')
plt.title(f'Urban Population Growth Trend in {country}')
plt.xlabel('Year')
plt.ylabel('Urban Population Growth (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot shows urban population growth trends across various countries, highlighting factors driving urbanization such as economic opportunities and infrastructure development. It reveals periods of rapid growth, indicating shifts in policies or global events. Understanding these trends is crucial for policymakers and urban planners to address the challenges and opportunities of increasing urbanization.

# %% [markdown]
# 11. How does tax revenue as a percentage of GDP vary by country?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='country', y='Tax Revenue (% GDP)', data=final)
plt.title(f'Tax Revenue (% GDP) Distribution in {year}')
plt.xlabel('Country')
plt.ylabel('Tax Revenue (% GDP)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This plot displays the distribution of tax revenue as a percentage of GDP across countries, offering insights into fiscal health and revenue strategies. It highlights variations in tax policies and identifies outliers, helping to assess the relationship between tax revenue and economic performance.

# %% [markdown]
# 12. What is the relationship between debt service and exports?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Debt Service (% Exports)', y='Exports (% GDP)', hue='country', data=final)
plt.title('Debt Service vs Exports')
plt.xlabel('Debt Service (% Exports)')
plt.ylabel('Exports (% GDP)')
plt.show()

# %% [markdown]
# This plot analyzes the relationship between debt service payments and exports across countries, revealing how export levels impact debt management. It highlights patterns that indicate economic resilience or vulnerability, providing insights for sustainable economic strategies.

# %% [markdown]
# 13. How does the adolescent fertility rate trend over time for a specific country?

# %%
country = 'India'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['Adolescent Fertility Rate'], marker='d', color='red')
plt.title(f'Adolescent Fertility Rate Trend in {country}')
plt.xlabel('Year')
plt.ylabel('Adolescent Fertility Rate')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot shows trends in adolescent fertility rates across countries, highlighting socio-economic factors and the impact of health initiatives. It identifies significant changes, helping policymakers understand the implications for youth empowerment and reproductive health strategies.

# %%
country = 'USA'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['Adolescent Fertility Rate'], marker='d', color='red')
plt.title(f'Adolescent Fertility Rate Trend in {country}')
plt.xlabel('Year')
plt.ylabel('Adolescent Fertility Rate')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot shows trends in adolescent fertility rates across countries, highlighting socio-economic factors and the impact of health initiatives. It identifies significant changes, helping policymakers understand the implications for youth empowerment and reproductive health strategies.

# %% [markdown]
# 14. What is the pairwise relationship between different indicators for a specific country?

# %%
country = 'USA'
country_data = final[final['country'] == country]

sns.pairplot(country_data[['Total Fertility Rate', 'CO2 Emissions (tons per capita)', 'Urban Population Growth (%)', 'Exports (% GDP)']])
plt.show()

# %% [markdown]
# This pair plot illustrates the relationships among Total Fertility Rate, CO2 Emissions per capita, Urban Population Growth, and Exports as a percentage of GDP. By visualizing these variables together, it highlights potential correlations, such as how urbanization may impact fertility rates and emissions, and the role of exports in economic growth. This analysis provides valuable insights for understanding the interplay between demographic trends and environmental and economic factors.

# %%
country = 'India'
country_data = final[final['country'] == country]

sns.pairplot(country_data[['Total Fertility Rate', 'CO2 Emissions (tons per capita)', 'Urban Population Growth (%)', 'Exports (% GDP)']])
plt.show()

# %% [markdown]
# This pair plot illustrates the relationships among Total Fertility Rate, CO2 Emissions per capita, Urban Population Growth, and Exports as a percentage of GDP. By visualizing these variables together, it highlights potential correlations, such as how urbanization may impact fertility rates and emissions, and the role of exports in economic growth. This analysis provides valuable insights for understanding the interplay between demographic trends and environmental and economic factors.

# %% [markdown]
# 15. How do protected areas as a percentage of total area compare between countries?

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='Protected Areas (% Total Area)', data=final)
plt.title(f'Protected Areas (% Total Area) by Country in {year}')
plt.xlabel('Country')
plt.ylabel('Protected Areas (% Total Area)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This bar plot displays the percentage of total land area designated as protected in each country, highlighting conservation efforts and biodiversity preservation. It allows for quick comparisons of countries' commitments to safeguarding natural habitats.

# %% [markdown]
# 16. What is the trend of secondary school enrollment over time for a specific country?

# %%
country = 'India'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['Secondary School Enrollment (% Gross)'], marker='o', color='green')
plt.title(f'Secondary School Enrollment Trend in {country}')
plt.xlabel('Year')
plt.ylabel('Secondary School Enrollment (% Gross)')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot shows trends in secondary school enrollment over time, illustrating changes in education access and participation rates across countries. It highlights progress and challenges in achieving educational goals.

# %%
country = 'USA'
country_data = final[final['country'] == country]

plt.figure(figsize=(10, 6))
plt.plot(country_data['year'], country_data['Secondary School Enrollment (% Gross)'], marker='o', color='green')
plt.title(f'Secondary School Enrollment Trend in {country}')
plt.xlabel('Year')
plt.ylabel('Secondary School Enrollment (% Gross)')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot shows trends in secondary school enrollment over time, illustrating changes in education access and participation rates across countries. It highlights progress and challenges in achieving educational goals.

# %% [markdown]
# 17. How does time to start a business vary across countries?

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='country', y='Time to Start Business (days)', data=final)
plt.title(f'Time to Start Business by Country in {year}')
plt.xlabel('Country')
plt.ylabel('Time to Start Business (days)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This box plot displays the variation in the time required to start a business across different countries, highlighting differences in regulatory environments and entrepreneurial conditions. It identifies outliers and trends in ease of doing business.

# %% [markdown]
# 18. What is the distribution of CO2 emissions using a pie chart for a given year?

# %%
plt.figure(figsize=(10, 6))
emission_data = final.groupby('country')['CO2 Emissions (tons per capita)'].sum()
plt.pie(emission_data, labels=emission_data.index, autopct='%1.1f%%')
plt.title(f'CO2 Emissions Distribution in {year}')
plt.show()

# %% [markdown]
# This pie plot illustrates the distribution of CO2 emissions per capita among different countries, highlighting their relative contributions to global emissions and providing insights into carbon footprints.

# %% [markdown]
# 19. How does surface area differ between countries?

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='Surface Area (sq km)', data=final)
plt.title(f'Surface Area by Country')
plt.xlabel('Country')
plt.ylabel('Surface Area (sq km)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# This bar plot displays the surface area of countries, allowing for easy comparison of their sizes. It highlights geographical diversity and can inform discussions on land use and resource management.

# %% [markdown]
# 20. What is the trend of urban population growth over time for a specific country?

# %%
top_population = final[['country', 'Total Population']].sort_values(by='Total Population', ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='Total Population', data=top_population)
plt.xticks(rotation=45)
plt.title('Most Populous Countries')
plt.xlabel('Country')
plt.ylabel('Total Population')
plt.show()

# %% [markdown]
# This bar plot ranks countries by population size, highlighting the most populous nations. It provides a clear visual representation of global population distribution and trends.

# %% [markdown]
# 21. How does the adolescent fertility rate trend over time for a specific country?

# %%
avg_adolescent_fertility = final.groupby('country')['Adolescent Fertility Rate'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='country', y='Adolescent Fertility Rate', data=avg_adolescent_fertility)
plt.xticks(rotation=45)
plt.title('Average Adolescent Fertility Rate by Region')
plt.xlabel('Region')
plt.ylabel('Adolescent Fertility Rate')
plt.show()

# %% [markdown]
# This bar plot compares the average adolescent fertility rates across different regions, highlighting disparities in reproductive health and education. It provides insights into the challenges faced by various areas in addressing teen pregnancy.

# %% [markdown]
# Key Observations:
# 1. CO2 Emissions Trends: The trend analysis of CO2 emissions for individual countries shows varying patterns. For countries with rapid industrialization, emissions tend to increase over time, while countries with environmental regulations in place may show a decline or stabilization.
#
# 2. Fertility Rates: The total fertility rates are higher in developing countries, with gradual declines over the years. This trend aligns with increased access to education, healthcare, and family planning services.
#
# 3. Urbanization and Emissions: There is a positive relationship between urban population growth and CO2 emissions. As urbanization increases, so do emissions, indicating the environmental challenges associated with urban expansion.
#
# 4. Economic Indicators:
#    - External Debt: For many countries, external debt has shown a steady rise over time, particularly in countries facing financial challenges or those heavily reliant on international funding.
#    - Exports and Debt Service: There is a strong relationship between a country's debt service and its export levels. Countries with higher exports tend to manage debt service more efficiently, highlighting the importance of trade for economic stability.
#
# 5. Skilled Birth Attendance: The variance in skilled birth attendance across countries reveals disparities in healthcare access. Developing countries tend to have lower rates of skilled birth attendance, which can be linked to higher maternal and infant mortality rates.
#
# 6. Agricultural Dependence: Countries that have a higher percentage of GDP coming from agriculture tend to be more vulnerable to climate change impacts. The reliance on agriculture suggests limited diversification in their economies.
#
# 7. Education:
#    - Secondary School Enrollment: Higher enrollment rates in secondary education are associated with countries that show progress in economic development, social welfare, and human capital growth.
#    - School Enrollment GPI: Countries with a higher GPI (Gender Parity Index) reflect better gender equality in education, promoting inclusive growth.
#
# 8. Protected Areas: The analysis of protected areas as a percentage of total land shows that countries with larger protected regions are prioritizing environmental conservation. This also reflects their commitment to biodiversity and sustainable land use.
#
# The dataset reflects both the diversity and complexity of social, environmental, and economic dynamics across countries. Developed countries generally exhibit more favorable indicators in terms of healthcare, education, and economic stability, while developing nations face challenges related to debt, fertility, and environmental sustainability. However, many countries show progress in various aspects, particularly in education, urbanization, and economic reform.
#
# Addressing the gaps between countries, particularly in health services (skilled birth attendance), education, and environmental protection, remains a global challenge. These visualizations underline the importance of policy interventions aimed at improving healthcare access, promoting sustainable urbanization, and ensuring economic growth is equitable and environmentally sustainable.
